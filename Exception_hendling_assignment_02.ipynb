# %% [markdown]
# Exception hendling assignment

# %%
#solution 1:

"""
we can define custom exceptions by creating a
new class that is derived from the built-in 
Exception class."""


class InvalidAgeException(Exception):
    "Raised when the input value is less than 18"
    pass

number = 18

try:
    input_num = int(input("Enter a number: "))
    if input_num < number:
        raise InvalidAgeException
    else:
        print("Eligible to Vote")
        
except InvalidAgeException:
    print("Exception occurred: Invalid Age")
# Out:
# Enter a number:  9
# Exception occurred: Invalid Age

# %%
#solution 2:

import inspect
import logging
def tcls(cls, ind=0):
    print('_'*ind,cls.__name__)
    for i in cls.__subclasses__():
        tcls(i, ind+3)
print("Hierarchy for built in exception is : ")
inspect.getclasstree(inspect.getmro(BaseException))
tcls(BaseException)
# Out:
# Hierarchy for built in exception is :
#  BaseException
# ___ Exception
# ______ TypeError
# _________ FloatOperation
# _________ MultipartConversionError
# ______ StopAsyncIteration
# ______ StopIteration
# ______ ImportError
# _________ ModuleNotFoundError
# _________ ZipImportError
# ______ OSError
# _________ ConnectionError
# ____________ BrokenPipeError
# ____________ ConnectionAbortedError
# ____________ ConnectionRefusedError
# ____________ ConnectionResetError
# _______________ RemoteDisconnected
# _________ BlockingIOError
# _________ ChildProcessError
# _________ FileExistsError
# _________ FileNotFoundError
# _________ IsADirectoryError
# _________ NotADirectoryError
# _________ InterruptedError
# ____________ InterruptedSystemCall
# _________ PermissionError
# _________ ProcessLookupError
# _________ TimeoutError
# _________ UnsupportedOperation
# _________ itimer_error
# _________ herror
# _________ gaierror
# _________ SSLError
# ____________ SSLCertVerificationError
# ...

# %%
#solution 3:

"""
ARITHMETIC ERROR
------------------
Tthis error is the base class for the all arithmetic related errors. 
--->    ZeroDivisionError
        OverflowError
        FloatingPointError

"""
#example 1:

try:
    1/0
except ArithmeticError as e:
    print(f"{e}, {e.__class__}")
# Out:
# division by zero, <class 'ZeroDivisionError'>

# %%
#example 2:

j = 5.0

try:
    for i in range(1, 1000):
        j = j**i
except ArithmeticError as e:
    print(f"{e}, {e.__class__}")
# Out:
# (34, 'Numerical result out of range'), <class 'OverflowError'>

# %%
#solution 4:

""" The LookupError exception in Python forms the base class for all exceptions that are 
raised when an index or a key is not found for a sequence or dictionary respectively.

You can use LookupError exception class to handle both IndexError and KeyError
exception classes."""

x = [1, 2, 3, 4]

print(x[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 11
#       3 """ The LookupError exception in Python forms the base class for all exceptions that are
#       4 raised when an index or a key is not found for a sequence or dictionary respectively.
#       5
#       6 You can use LookupError exception class to handle both IndexError and KeyError
#       7 exception classes."""
#       9 x = [1, 2, 3, 4]
# ---> 11 print(x[5])
#
# IndexError: list index out of range

# %%
dict1 = {'name': 'Lenin Mishra',
                'age': 28,
                'language': 'Python'}
user_input = input('What do you want to learn about Pylenin==> ')

try:
    print(f'{user_input} is {dict1[user_input]}')
except LookupError as e:
    print(f'{e}, {e.__class__}')
# Out:
# What do you want to learn about Pylenin==>  4154
# '4154', <class 'KeyError'>

# %%
#solution 5:

""" 
ImportError:
--------------

we use “import” when we want to import any specific module
 when importing any module and there is any trouble in importing
 modules to the program then there is a chance of ImportError occurrence.
 
 There are two conditions when the ImportError will be raised. They are

--->If the module does not exist.
--->If we are trying to import submodule from the module

"""


import request
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 19
#       1 #solution 5:
#       3 """
#       4 ImportError:
#       5 --------------
#    (...)
#      15
#      16 """
# ---> 19 import request
#
# ModuleNotFoundError: No module named 'request'

# %%
#solution 6:

#1.

import logging
logging.basicConfig(filename="error.log" ,level=logging.ERROR)
try:
    10/0
except ZeroDivisionError as e:
    logging.error("u am trying to divided by zero{}".format(e))

# %%
#2:

try:
    10/0
except FileNotFoundError as e:
     logging.error("u am trying to divided by zero{}".format(e))
except ZeroDivisionError as e:
     logging.error("u am trying to divided by zero{}".format(e))
except AttributeError as e:
     logging.error("u am trying to divided by zero{}".format(e))

# %%
#3.

try:
    with open("text.txt","w") as f:
        f.write("this is my data")
except FileNotFoundError as e:
     logging.error("u am trying to divided by zero{}".format(e))
finally:
    f.close()
